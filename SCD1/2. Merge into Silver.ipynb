-- %%
select * from dev.bronze.invoice_al_3 i

-- %% [markdown]
-- this code is added to check if git is working or not.

-- %% [markdown]
-- this section is not in the remote repo yet

-- %% [markdown]
-- this is in test branch
